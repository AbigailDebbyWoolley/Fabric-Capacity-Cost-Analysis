# %%
import pandas as pd
df = pd.read_csv("fabric_capacity_units.csv")
df.head()
# Out:
#         Workspace        Item kind  \
# 0  MDP-FABRIC-PRD  SynapseNotebook
# 1  MDP-FABRIC-PRD  SynapseNotebook
# 2  MDP-FABRIC-PRD  SynapseNotebook
# 3  MDP-FABRIC-PRD  SynapseNotebook
# 4  MDP-FABRIC-PRD  SynapseNotebook
#
#                                     Item name        CU (s)  Duration (s)  \
# 0               NB_Infor_101_Ingest_Notebooks  4.940390e+06    105499.564
# 1  NB_Infor_100_Refresh_ReplicationSet_And_GL  2.066267e+06     44836.920
# 2                   NB_LEM_402_Gold_Notebooks  1.468763e+06     55608.916
# 3                  NB_Delta_Table_Maintenance  1.261594e+06     48555.112
# 4          NB_FieldForce_101_Ingest_Notebooks  8.909983e+05     27981.484
#
#    Users  Successful count  Failed count Billing type
# 0      1                 0             0     Billable
# 1      1                 0             0     Billable
# 2      1                 0             0     Billable
# 3      1                 0             0     Billable
# 4      1                 0             0     Billable

# %%
import pandas as pd

def clean_data(df):
    """Cleans and preprocesses the given DataFrame by:
    - Removing the last row if 'Item name' contains NaN
    - Dropping unnecessary columns
    - Renaming columns for consistency
    - Converting CU(s) to CU(h)

    Args:
        df (pd.DataFrame): The input DataFrame.

    Returns:
        pd.DataFrame: The cleaned DataFrame.
    """
    # Define columns to drop and rename
    columns_to_drop = {
        "Billing type",
        "Users",
        "Workspace",
        "Item kind",
        "Successful count",
        "Failed count",
        "Duration (s)",
    }

    rename_dict = {
        "Item name": "Item_name",
        "CU (s)": "CU(s)",
        "Duration (s)": "Duration(s)",
    }

    # Remove last row if 'Item name' is NaN
    if not df.empty and pd.isna(df.iloc[-1]["Item_name"]):
        df = df.iloc[:-1]

    # Drop unnecessary columns (ignore if they don't exist)
    df = df.drop(columns=columns_to_drop, errors="ignore")

    # Rename columns safely
    df = df.rename(columns=rename_dict)

    # Convert CU(s) to CU(h) if CU(s) exists
    if "CU(s)" in df.columns:
        df["CU(h)"] = df["CU(s)"] / 3600

    return df

# %%
df = clean_data(df)
df
# Out:
#                                             Item_name         CU(s)  \
# 0                       NB_Infor_101_Ingest_Notebooks  4.940390e+06
# 1          NB_Infor_100_Refresh_ReplicationSet_And_GL  2.066267e+06
# 2                           NB_LEM_402_Gold_Notebooks  1.468763e+06
# 3                          NB_Delta_Table_Maintenance  1.261594e+06
# 4                  NB_FieldForce_101_Ingest_Notebooks  8.909983e+05
# 5   NB_Infor_100_GeneralLedgerTransactionDetail_Sm...  7.994571e+05
# 6   NB_Infor_100_GeneralLedgerTransactionDetail_Sm...  5.611208e+05
# 7                         NB_LEM_101_Ingest_Notebooks  5.249229e+05
# 8   NB_Infor_100_GeneralLedgerTransactionDetail_Sm...  4.209588e+05
# 9                       NB_Coupa_101_Ingest_Notebooks  3.867237e+05
# 10                     GLDetailMissingRecordsAnalysis  3.705429e+05
# 11                    PL_Quantify_100_IngestMaster_AT  1.851667e+05
# 12                                      PL_BRS_JCD_AT  1.695600e+05
# 13                                   spark_payroll_NB  8.922445e+04
# 14                             FieldForceTableSummary  7.589102e+04
# 15               NB_Coupa_100_Purchase_Order_Lines_AT  5.427551e+04
# 16                                  InforTableSummary  2.297610e+04
# 17                                NB_Update_Watermark  1.713930e+04
# 18         0d4e3355-90cf-4720-ac19-e62b6da2a9a5.ipynb  1.114028e+04
# 19                          PL_FieldForce_CosmosDB_AT  5.322240e+03
# 20                      PL_LEM_100_ReportingMaster_AT  5.060160e+03
# 21                             NB_FieldForce_CosmosDB  4.854047e+03
# 22                         NB_Quantify_Curated_Tables  4.664448e+03
# 23                PL_LEM_401_ReportingOrchestrator_AT  3.971520e+03
# 24                         PL_LEM_100_IngestMaster_AT  2.701440e+03
# 25                 PL_Infor_101_IngestOrchestrator_AT  2.318400e+03
# 26                   PL_LEM_101_IngestOrchestrator_AT  1.370880e+03
# 27                       PL_Infor_100_IngestMaster_AT  1.149120e+03
# 28                   PL_Infor_100_GLDetail_Refresh_AT  8.265600e+02
# 29                       PL_Coupa_100_IngestMaster_AT  5.241600e+02
# 30                      PL_Delta_Table_Maintenance_AT  2.822400e+02
# 31                  PL_FieldForce_100_IngestMaster_AT  2.822400e+02
# 32            PL_FieldForce_101_IngestOrchestrator_AT  2.822400e+02
# 33                             NB_PipelineStatusEmail  1.391205e+02
#
#           CU(h)
# 0   1372.330577
# 1    573.962971
# 2    407.989584
# 3    350.442647
# 4    247.499536
# 5    222.071407
# 6    155.866878
# 7    145.811905
# 8    116.932999
# 9    107.423238
# 10   102.928595
# 11    51.435200
# 12    47.100000
# 13    24.784569
# 14    21.080840
# 15    15.076531
# 16     6.382251
# 17     4.760916
# 18     3.094523
# 19     1.478400
# 20     1.405600
# 21     1.348346
# 22     1.295680
# 23     1.103200
# 24     0.750400
# 25     0.644000
# 26     0.380800
# 27     0.319200
# 28     0.229600
# 29     0.145600
# 30     0.078400
# 31     0.078400
# 32     0.078400
# 33     0.038645

# %% [markdown]
# ### CU Calculation basedon Sku Type

# %%
def calculate_CU_allocation(sku_capacity, period="day"):
    """Calculates CU allocation in seconds and hours for a given SKU capacity and time period.

    Args:
        sku_capacity (int): The CU capacity of the SKU (e.g., 64 for F64).
        period (str): The time period for calculation. Options: "hour", "day", "month", "year".

    Returns:
        dict: A dictionary with CU-seconds and CU-hours for the specified period.
    """
    # Time conversion factors
    seconds_per_minute = 60
    minutes_per_hour = 60
    hours_per_day = 24
    days_per_month = 30
    days_per_year = 365

    # Define period multipliers
    period_multipliers = {
        "hour": 1 / hours_per_day,  # 1/24 of a day
        "day": 1,
        "month": days_per_month,
        "year": days_per_year
    }

    if period not in period_multipliers:
        raise ValueError("Invalid period. Choose from 'hour', 'day', 'month', or 'year'.")

    # Compute total CU allocation
    multiplier = period_multipliers[period]
    total_CU_seconds = sku_capacity * seconds_per_minute * minutes_per_hour * hours_per_day * multiplier
    total_CU_hours = total_CU_seconds / 3600  # Convert to CU-hours

    return {
        "CU-seconds": total_CU_seconds,
        "CU-hours": total_CU_hours
    }

# Example usage
sku_capacity = 64  # Example SKU type (F64)
period = "day"  # Can be "hour", "day", "month", or "year"

cu_allocation = calculate_CU_allocation(sku_capacity, period)

print(
    f"Total CU Allocation for SKU {sku_capacity} ({period}):\n"
    f" - {cu_allocation['CU-seconds']:,} CU-seconds\n"
    f" - {cu_allocation['CU-hours']:,} CU-hours"
)
# Out:
# Total CU Allocation for SKU 64 (day):
#  - 5,529,600 CU-seconds
#  - 1,536.0 CU-hours

# %%
# Define global cost rates
TOTAL_DAILYCOST_PAYG = 11.52 * 24
TOTAL_DAILYCOST_RESERVED = 6.853 * 24
TOTAL_CU_HOURS = 1536
WEEK = 7
MONTH = 30
YEAR = 356


def calculate_execution_costs(df_filtered):
    """
    Calculate PAYG and Reserved cost per execution based on Compute Unit (CU) usage.

    Parameters:
    df_filtered (pd.DataFrame): Input DataFrame containing CU(h) column.
    total_CU_hours (int, optional): Total Compute Units per hour for the given capacity. Default is 1536 for F64.

    Returns:
    pd.DataFrame: Updated DataFrame with PAYG and Reserved costs.
    """

    # Calculate cost per execution
    df_filtered = df_filtered.copy()
    df_filtered["PAYG Cost($)"] = (
        (df_filtered["CU(h)"] / 14) / TOTAL_CU_HOURS
    ) * TOTAL_DAILYCOST_PAYG
    df_filtered["Reserved Cost($)"] = (
        (df_filtered["CU(h)"] / 14) / TOTAL_CU_HOURS
    ) * TOTAL_DAILYCOST_RESERVED

    print("Cost Per Day for Each Execution")
    return df_filtered


df_filtered = calculate_execution_costs(df)
df_filtered
# Out:
# Cost Per Day for Each Execution
#                                             Item_name         CU(s)  \
# 0                       NB_Infor_101_Ingest_Notebooks  4.940390e+06
# 1          NB_Infor_100_Refresh_ReplicationSet_And_GL  2.066267e+06
# 2                           NB_LEM_402_Gold_Notebooks  1.468763e+06
# 3                          NB_Delta_Table_Maintenance  1.261594e+06
# 4                  NB_FieldForce_101_Ingest_Notebooks  8.909983e+05
# 5   NB_Infor_100_GeneralLedgerTransactionDetail_Sm...  7.994571e+05
# 6   NB_Infor_100_GeneralLedgerTransactionDetail_Sm...  5.611208e+05
# 7                         NB_LEM_101_Ingest_Notebooks  5.249229e+05
# 8   NB_Infor_100_GeneralLedgerTransactionDetail_Sm...  4.209588e+05
# 9                       NB_Coupa_101_Ingest_Notebooks  3.867237e+05
# 10                     GLDetailMissingRecordsAnalysis  3.705429e+05
# 11                    PL_Quantify_100_IngestMaster_AT  1.851667e+05
# 12                                      PL_BRS_JCD_AT  1.695600e+05
# 13                                   spark_payroll_NB  8.922445e+04
# 14                             FieldForceTableSummary  7.589102e+04
# 15               NB_Coupa_100_Purchase_Order_Lines_AT  5.427551e+04
# 16                                  InforTableSummary  2.297610e+04
# 17                                NB_Update_Watermark  1.713930e+04
# 18         0d4e3355-90cf-4720-ac19-e62b6da2a9a5.ipynb  1.114028e+04
# 19                          PL_FieldForce_CosmosDB_AT  5.322240e+03
# 20                      PL_LEM_100_ReportingMaster_AT  5.060160e+03
# 21                             NB_FieldForce_CosmosDB  4.854047e+03
# 22                         NB_Quantify_Curated_Tables  4.664448e+03
# 23                PL_LEM_401_ReportingOrchestrator_AT  3.971520e+03
# 24                         PL_LEM_100_IngestMaster_AT  2.701440e+03
# 25                 PL_Infor_101_IngestOrchestrator_AT  2.318400e+03
# 26                   PL_LEM_101_IngestOrchestrator_AT  1.370880e+03
# 27                       PL_Infor_100_IngestMaster_AT  1.149120e+03
# 28                   PL_Infor_100_GLDetail_Refresh_AT  8.265600e+02
# 29                       PL_Coupa_100_IngestMaster_AT  5.241600e+02
# 30                      PL_Delta_Table_Maintenance_AT  2.822400e+02
# 31                  PL_FieldForce_100_IngestMaster_AT  2.822400e+02
# 32            PL_FieldForce_101_IngestOrchestrator_AT  2.822400e+02
# 33                             NB_PipelineStatusEmail  1.391205e+02
#
#           CU(h)  PAYG Cost($)  Reserved Cost($)
# 0   1372.330577     17.644250         10.496185
# 1    573.962971      7.379524          4.389920
# 2    407.989584      5.245580          3.120483
# 3    350.442647      4.505691          2.680339
# 4    247.499536      3.182137          1.892985
# 5    222.071407      2.855204          1.698499
# 6    155.866878      2.004003          1.192138
# 7    145.811905      1.874724          1.115233
# 8    116.932999      1.503424          0.894355
# 9    107.423238      1.381156          0.821620
# 10   102.928595      1.323368          0.787243
# 11    51.435200      0.661310          0.393399
# 12    47.100000      0.605571          0.360241
# 13    24.784569      0.318659          0.189563
# 14    21.080840      0.271039          0.161235
# 15    15.076531      0.193841          0.115312
# 16     6.382251      0.082058          0.048814
# 17     4.760916      0.061212          0.036414
# 18     3.094523      0.039787          0.023668
# 19     1.478400      0.019008          0.011307
# 20     1.405600      0.018072          0.010751
# 21     1.348346      0.017336          0.010313
# 22     1.295680      0.016659          0.009910
# 23     1.103200      0.014184          0.008438
# 24     0.750400      0.009648          0.005739
# 25     0.644000      0.008280          0.004926
# 26     0.380800      0.004896          0.002913
# 27     0.319200      0.004104          0.002441
# 28     0.229600      0.002952          0.001756
# 29     0.145600      0.001872          0.001114
# 30     0.078400      0.001008          0.000600
# 31     0.078400      0.001008          0.000600
# 32     0.078400      0.001008          0.000600
# 33     0.038645      0.000497          0.000296
